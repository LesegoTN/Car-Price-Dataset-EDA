# %% [markdown]
# # Minor Project Exam: Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Problem statement:
# Perform exploratory data analysis (EDA) on the given dataset using Python libraries such as Numpy, Pandas, and Matplotlib/Seaborn. The goal is to uncover underlying patterns, relationships, and insights from the data.
#
# ##### Additionally, document your process with Python comments explaining your code, and for each section, provide detailed conclusions and observations.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Section 1: Understanding the Dataset

# %% [markdown]
# #### 1.1	Load Data: Import the dataset into your working environment using appropriate methods or libraries.

# %%
df = pd.read_csv('car_price_dataset.csv')

# %% [markdown]
# #### 1.2	Checking Data Shape: Determine the shape of your dataset, including the number of rows and columns.

# %%
df.shape # Obeservation: 15411 rows and 14 columns
# Out:
# (15411, 14)

# %% [markdown]
# #### 1.3	View Data: Display the first and last few rows of the dataset and summarize any initial insights.

# %%
#Displaying the first 10 rows of the dataset
df.head(10)
# Out:
#    Unnamed: 0        car_name    brand     model  vehicle_age  km_driven  \
# 0           0     Maruti Alto   Maruti      Alto            9     120000
# 1           1   Hyundai Grand  Hyundai     Grand            5      20000
# 2           2     Hyundai i20  Hyundai       i20           11      60000
# 3           3     Maruti Alto   Maruti      Alto            9      37000
# 4           4   Ford Ecosport     Ford  Ecosport            6      30000
# 5           5  Maruti Wagon R   Maruti   Wagon R            8      35000
# 6           6     Hyundai i10  Hyundai       i10            8      40000
# 7           7  Maruti Wagon R   Maruti   Wagon R            3      17512
# 8           8   Hyundai Venue  Hyundai     Venue            2      20000
# 9          12    Maruti Swift   Maruti     Swift            4      28321
#
#   seller_type fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0  Individual    Petrol            Manual    19.70     796      46.30      5
# ...

# %%
# Displaying the last 10 rows of the dataset
df.tail(10)
# Out:
#        Unnamed: 0         car_name     brand   model  vehicle_age  km_driven  \
# 15401       19531     Maruti Swift    Maruti   Swift            3      25000
# 15402       19533      Honda Amaze     Honda   Amaze            6      28000
# 15403       19534     Renault KWID   Renault    KWID            2       2700
# 15404       19535    Maruti Ertiga    Maruti  Ertiga            5      56829
# 15405       19536    Hyundai Grand   Hyundai   Grand            5       9229
# 15406       19537      Hyundai i10   Hyundai     i10            9      10723
# 15407       19540    Maruti Ertiga    Maruti  Ertiga            2      18000
# 15408       19541      Skoda Rapid     Skoda   Rapid            6      67000
# 15409       19542  Mahindra XUV500  Mahindra  XUV500            5    3800000
# 15410       19543       Honda City     Honda    City            2      13000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# ...

# %%
'''
Observations:

The dataset used in this analysis contains information about car prices and their associated features.

There are 15411 rows and 14 columns in this dataset.
There is an unamed column that will potentially need to be dropped as from first glance it doesn't appear to have an influence to our data (it appears to be indexing or numbering). 
In total there are features such as: 'car_name', 'brand', 'model', 'vehicle_age', 'km_driven', 'seller_type' (Individual/Dealer), 'fuel_type' (Petrol/Diesel), 'transmission_type' (Automatic/Manual), 'milage', 'engine', 'max_power', 'seats' and 'selling_price'.
'''
# Out:
# "\nObservations:\n\nThe dataset used in this analysis contains information about car prices and their associated features.\n\nThere are 15411 rows and 14 columns in this dataset.\nThere is an unamed column that will potentially need to be dropped as from first glance it doesn't appear to have an influence to our data (it appears to be indexing or numbering). \nIn total there are features such as: 'car_name', 'brand', 'model', 'vehicle_age', 'km_driven', 'seller_type' (Individual/Dealer), 'fuel_type' (Petrol/Diesel), 'transmission_type' (Automatic/Manual), 'milage', 'engine', 'max_power', 'seats' and 'selling_price'.\n"

# %% [markdown]
# ### Section 2: Initial Data Examination

# %% [markdown]
# #### 2.1	Dataset Information: Provide a concise summary of the dataset, including the number of non-null entries, and explain what this reveals.

# %%
# Printing information about the dataframe
# The information contains the number of columns, column labels, column data types, memory usage, range index, and the number of cells in each column (non-null values)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         15411 non-null  int64
#  1   car_name           15411 non-null  object
#  2   brand              15411 non-null  object
#  3   model              15411 non-null  object
#  4   vehicle_age        15411 non-null  int64
#  5   km_driven          15411 non-null  int64
#  6   seller_type        15411 non-null  object
#  7   fuel_type          15411 non-null  object
#  8   transmission_type  15411 non-null  object
#  9   mileage            15411 non-null  float64
#  10  engine             15411 non-null  int64
#  11  max_power          15411 non-null  float64
#  12  seats              15411 non-null  int64
#  13  selling_price      15411 non-null  int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 1.6+ MB

# %%
#df.isnull().sum()
# We can confirm that our dataset has no null entries by using the isnull() function in conjucntion with sum() function

# %%
''' 
Observations:

There are 14 columns (13 features, 1 index column which we've dropped) in this dataset, each with 15411 non-null entries. 
This reveals that there are no missing values in the dataset. 
Additionally, most features are correctly represented by their current data types: object type for strings (text) type features, integer type for integer features (whole numbers), and float type for features with decimal values. However, there are categorical features in our dataset as well (namely: seller_type, fuel_type and transmission_type) which it would be useful to convert into categorical data types.
'''
# Out:
# " \nObservations:\n\nThere are 14 columns (13 features, 1 index column which we've dropped) in this dataset, each with 15411 non-null entries. \nThis reveals that there are no missing values in the dataset. \nAdditionally, most features are correctly represented by their current data types: object type for strings (text) type features, integer type for integer features (whole numbers), and float type for features with decimal values. However, there are categorical features in our dataset as well (namely: seller_type, fuel_type and transmission_type) which it would be useful to convert into categorical data types.\n"

# %% [markdown]
# #### 2.2 Inspect Data Types: Check data type of each column in the dataset. If columns need any data type conversion, update the data type accordingly and describe the rationale behind the conversions.

# %%
# Checking data types of each column
df.dtypes
# Out:
# Unnamed: 0             int64
# car_name              object
# brand                 object
# model                 object
# vehicle_age            int64
# km_driven              int64
# seller_type           object
# fuel_type             object
# transmission_type     object
# mileage              float64
# engine                 int64
# max_power            float64
# seats                  int64
# selling_price          int64
# dtype: object

# %%
# Changing data type using astype
# Changing below features from object data type to categorical data type 

df['seller_type']= df['seller_type'].astype('category')
df['fuel_type']= df['fuel_type'].astype('category')
df['transmission_type']= df['transmission_type'].astype('category')

# Verify Change 
df.dtypes
# Out:
# Unnamed: 0              int64
# car_name               object
# brand                  object
# model                  object
# vehicle_age             int64
# km_driven               int64
# seller_type          category
# fuel_type            category
# transmission_type    category
# mileage               float64
# engine                  int64
# max_power             float64
# seats                   int64
# selling_price           int64
# dtype: object

# %%
'''
Observation:

Changing the data types of features: seller_type, fuel_type and transmission type from object to category for the purpose of feature engineering (encoding). 
These columns were selected because they contain meaningful labels: seller_type has labels dealer/individual; fuel_type has labels petrol/diesel; and transmission type has labels automatic/manual.
This change will be useful for fatser operations such as grouping, sorting and filtering allowing for better summaries and machine learning operations.

'''
# Out:
# '\nObservation:\n\nChanging the data types of features: seller_type, fuel_type and transmission type from object to category for the purpose of feature engineering (encoding). \nThese columns were selected because they contain meaningful labels: seller_type has labels dealer/individual; fuel_type has labels petrol/diesel; and transmission type has labels automatic/manual.\nThis change will be useful for fatser operations such as grouping, sorting and filtering allowing for better summaries and machine learning operations.\n\n'

# %% [markdown]
# #### 2.3 Summary Statistics: Generate summary statistics for the numerical columns and interpret what these statistics tell you about the data.

# %%
# Summary of Stastistics (of numerical columns)
df.describe()
# Out:
#          Unnamed: 0   vehicle_age     km_driven       mileage        engine  \
# count  15411.000000  15411.000000  1.541100e+04  15411.000000  15411.000000
# mean    9811.857699      6.036338  5.561648e+04     19.701151   1486.057751
# std     5643.418542      3.013291  5.161855e+04      4.171265    521.106696
# min        0.000000      0.000000  1.000000e+02      4.000000    793.000000
# 25%     4906.500000      4.000000  3.000000e+04     17.000000   1197.000000
# 50%     9872.000000      6.000000  5.000000e+04     19.670000   1248.000000
# 75%    14668.500000      8.000000  7.000000e+04     22.700000   1582.000000
# max    19543.000000     29.000000  3.800000e+06     33.540000   6592.000000
#
#           max_power         seats  selling_price
# count  15411.000000  15411.000000   1.541100e+04
# mean     100.588254      5.325482   7.749711e+05
# std       42.972979      0.807628   8.941284e+05
# min       38.400000      0.000000   4.000000e+04
# ...

# %%
''' 
Observations:

Descriptive statistics include those that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding null-values values. This includes: 
- count: which tells us how many non missing values each column has. Each column has 15411 non-missing entries further confirming that our data has no missing values (our data is complete).
- mean: gives the average value of each column. For selling_price (target variable) the mean is higher than the median this hints that our data distribution might be skewed (perhaps due to outliers); km_driven has a relatively high mean, which indicates that most cars have been fairly used (second hand); engine_size also has a mean higher than median which means this column data is right-skewed.
- std: shows the spread of our data. selling_price has a high std which indicates that prices vary a lot; km_driven also has a high std which indicates that the usage of the cars varies, some are highly driven while others not; milage and seats have relatively low dispertion.
- min: seats has a minimun value of 0 which is unralistic for a car, this is likely a data entry error.
- max: engine and max_power have extremely high values which point to outliers.
- quartiles: shows the 25%, 50% and 75% quartiles which descibe how the data is distributed. We observe that for selling_price,engine, max_power the median is closer to the lower quartile (25% quartile )than the upper (75% quartile) which meand the data for those columns is right-skewed


We can also assertain from the descriptive statistics that selling_price, a dependent variable is a numerical column.
'''
# Out:
# ' \nObservations:\n\nDescriptive statistics include those that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding null-values values. This includes: \n- count: which tells us how many non missing values each column has. Each column has 15411 non-missing entries further confirming that our data has no missing values (our data is complete).\n- mean: gives the average value of each column. For selling_price (target variable) the mean is higher than the median this hints that our data distribution might be skewed (perhaps due to outliers); km_driven has a relatively high mean, which indicates that most cars have been fairly used (second hand); engine_size also has a mean higher than median which means this column data is right-skewed.\n- std: shows the spread of our data. selling_price has a high std which indicates that prices vary a lot; km_driven also has a high std which indicates that the usage of the cars varies, some are highly driven while
# ...

# %% [markdown]
# #### 2.4 Provide detailed comments that explain your understanding of the data.

# %%
''' The dataset contains a certain number of rows, each representing a unique car entry, and a set of columns describing various attributes of the cars.

Columns: The dataset consists of several columns including:

    Car Name: The brand or manufacturer of the car including the model/make (e.g., Hyundia i10, Honda Civic, Ford Figo).
    Brand : The brand or manufacturer of the car (e.g., Hyundia, Honda, Ford )
    Model: The specific model of the car (e.g., Swift, Civic, XUV500).
    Vehicle Age: The age of the vehicle.
    km_driven: The total mileage (in km) of the car.
Seller Type: 
    Fuel Type: petrol/diesel
    Transmission Type: automatic/manual 
    Mileage: Fuel efficiency 
    Engine: Engine size
    Max Power: (Max) Power of the car 
    Seats: Number of seats of the car   
    Selling Price: The price of the car. 

Selling Price is our target variable (dependent variable) and the rest are independent variables (i.e. Features).

There are three data types in our dataset: object (car_name, brand, model), integerts (vehicle_age, km_driven, engine, seats, selling_price), and categorical (seller_type, fuel_type,transmission_type). 

The shape of our dataset is 15411 rows and 14 columns (13 features and 1 index column to be dropped) and each column consists of 15411 entries so our dataset consist of no null-values. 

Overall, selling_price, engine, and max_power are right-skewed variables. While milage is relatively symmetric. 

Seats column has an anomally of minimum of 0 seats recorded which doesnt make logical sense. This column will have to be cleaned.
'''
# Out:
# ' The dataset contains a certain number of rows, each representing a unique car entry, and a set of columns describing various attributes of the cars.\n\nColumns: The dataset consists of several columns including:\n\n    Car Name: The brand or manufacturer of the car including the model/make (e.g., Hyundia i10, Honda Civic, Ford Figo).\n    Brand : The brand or manufacturer of the car (e.g., Hyundia, Honda, Ford )\n    Model: The specific model of the car (e.g., Swift, Civic, XUV500).\n    Vehicle Age: The age of the vehicle.\n    km_driven: The total mileage (in km) of the car.\nSeller Type: \n    Fuel Type: petrol/diesel\n    Transmission Type: automatic/manual \n    Mileage: Fuel efficiency \n    Engine: Engine size\n    Max Power: (Max) Power of the car \n    Seats: Number of seats of the car   \n    Selling Price: The price of the car. \n\nSelling Price is our target variable (dependent variable) and the rest are independent variables (i.e. Features).\n\nThere are three data typ
# ...

# %% [markdown]
# ### Section 3: Data Cleaning

# %%
df.drop(['Unnamed: 0' ], axis=1,inplace=True) #Drop index column thats auto created

# %% [markdown]
# #### 3.1 Handling Missing Values: Identify missing values in the dataset and describe how you handled them, including your chosen method.

# %%
# There are no missing values in our dataset. There are 13 columns and 15411 rows and each row has 15411 entries.

# Verifying no missing values
df.isnull().sum() #Count missing values per column
# Out:
# car_name             0
# brand                0
# model                0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %% [markdown]
# #### 3.2 Handling Duplicates: Check for duplicate rows in the dataset and describe your approach to handling any duplicates found.

# %%
# Check for duplicates using 'duplicated()' function
print(" Number of duplicates:", df.duplicated().sum() ) # Number of duplicate rows

# Display duplicate rows
print( df[ df.duplicated() ] )

# Remove duplicates using .drop_duplicates()
df = df.drop_duplicates( keep='last')
print("New shape of dataframe after dropping duplicates:", df.shape)
# Out:
#  Number of duplicates: 167
#                  car_name       brand        model  vehicle_age  km_driven  \
# 197            Honda City       Honda         City            8      70000
# 360         Maruti Baleno      Maruti       Baleno            2       5000
# 1353   Maruti Swift Dzire      Maruti  Swift Dzire            4      50000
# 1429       Maruti Wagon R      Maruti      Wagon R           13     100000
# 1485          Hyundai i20     Hyundai          i20            3      50000
# ...                   ...         ...          ...          ...        ...
# 15229        Maruti Swift      Maruti        Swift            8      80000
# 15324      Maruti Wagon R      Maruti      Wagon R            6      50000
# 15367          Tata Tiago        Tata        Tiago            4      30000
# 15378       Hyundai Grand     Hyundai        Grand            6      30000
# 15392    Land Rover Rover  Land Rover        Rover            5     128000
#
# ...

# %%
# Reset index after dropping rows
df.reset_index(drop=True, inplace=True) 
df.tail() #Checking if indexes are dropped
# Out:
#               car_name     brand   model  vehicle_age  km_driven seller_type  \
# 15239      Hyundai i10   Hyundai     i10            9      10723      Dealer
# 15240    Maruti Ertiga    Maruti  Ertiga            2      18000      Dealer
# 15241      Skoda Rapid     Skoda   Rapid            6      67000      Dealer
# 15242  Mahindra XUV500  Mahindra  XUV500            5    3800000      Dealer
# 15243       Honda City     Honda    City            2      13000      Dealer
#
#       fuel_type transmission_type  mileage  engine  max_power  seats  \
# 15239    Petrol            Manual    19.81    1086      68.05      5
# 15240    Petrol            Manual    17.50    1373      91.10      7
# 15241    Diesel            Manual    21.14    1498     103.52      5
# 15242    Diesel            Manual    16.00    2179     140.00      7
# 15243    Petrol         Automatic    18.00    1497     117.60      5
#
#        selling_price
# 15239         250000
# 15240         925000
# ...

# %% [markdown]
# #### 3.3 Outliers removal: Check if there are any outliers and remove them using graphical/non-graphical methods.

# %%
# Creatinag a separate dataframe for numerical columns only
num_df = df.select_dtypes(include = "number")
num_df

# Plot separate boxplots for each column
for col in num_df.columns:
    plt.figure(figsize=(6, 4))
    sns.boxplot(y=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
# Using statistical method to calculate upper and lower limits using quantiles for all numerical columns 
for col in num_df.columns:
    # Heading for each column iteration
    print("\n===================================")
    print("COLUMN:", col)
    print("===================================")
    
    # 1. Calculating quartiles (25% quartile and 75% quartile):
    q1 = np.quantile(df[col], 0.25)
    q3 = np.quantile(df[col], 0.75)
    print("Q1 (25th percentile):", q1)
    print("Q3 (75th percentile):", q3)
    
    # 2. Calculating IQR:
    IQR = q3 - q1
    print("IQR:", IQR)
    
    # 3. Calculating limits:
    lower_limit = q1 - 1.5*IQR
    upper_limit = q3 + 1.5*IQR
    print("Lower limit:", lower_limit)
    print("Upper limit:", upper_limit)
    
    # 4. Finding outlier row indexes
    index_list = df.index[ (df[col] < lower_limit) | (df[col] > upper_limit) ]
    print("Outlier row indexes:", index_list.tolist())
    print("Number of outliers:", len(index_list))
    
    # 5. Using upper and lower lintis to remove outlier instances (rows)
    df = df.drop(index_list).reset_index(drop=True)
    print("Dataset shape after dropping:", df.shape)
    
print("\nFinal dataset shape:", df.shape)
# Out:
# ...
# COLUMN: vehicle_age
# ...
# Q1 (25th percentile): 4.0
# Q3 (75th percentile): 8.0
# IQR: 4.0
# Lower limit: -2.0
# Upper limit: 14.0
# ...

# %% [markdown]
# #### 3.4 Add python comments to explain the observations.

# %%
'''
1. Missing values: there are no missing values in our dataset.Each column has 15411 entries. We used the df.isnull().sum() to count the missing values per column, which returned zero for each column thust verifying that there are no missing values in our dataset.
2. Duplicates: there are 167 duplicated rows in our dataframe. We used the .drop_duplicates() to drop the duplicated rows, which left us with a dataframe of 15244 rows and 13 columns.
3. Outliers: The outlier analysis revealed the presence of extreme values across multiple numerical variables, particularly in price-related features, indicating a skewed distribution and the need for careful preprocessing before modeling.
            For vehicle_age : most cars fall within a reasonable age range, the outliers are very old or very new cars.
            For km_driven: there are a large amount of outliers present in this column. These are cars with very high milage, from this we see that some cars are driven much more than average (likely due to long-distance use or being used as fleet cars). High milage will affetct the selling price.
            Milage: has fewer outliers than km_driven. The outliers here likely represent cars with high fuel efficiency or with poor fuel effciency. With there being fewer outliers in this column we can deduce that most cars have a similar fuel efficiency.
            Engine: has many outliers, large engine sizes are most notable meaning most cars have small to mid-sized engine sizes making large engines out of the norm.
            Max_power: most cars exeplify as normal 'everyday' cars which makes high-performance cars uncommon and outliers.T
            Seats: Many values are flagged as outliers. This is because most cars have 5 seats so anything else stands out statistically as an outlier.
            Selling_price: this column has significant outliers. There are cars priced significantly above the typical price range which tells us that the price distribution is rightly-skewed.These high prices could be due to luxury/premium vehicles (which is rare as most present as everyday cars).
    Overall most cars are normal cars. Outliers would represent cars with high selling price, high milage or large engine sizes.
            
'''
# Out:
# "\n1. Missing values: there are no missing values in our dataset.Each column has 15411 entries. We used the df.isnull().sum() to count the missing values per column, which returned zero for each column thust verifying that there are no missing values in our dataset.\n2. Duplicates: there are 167 duplicated rows in our dataframe. We used the .drop_duplicates() to drop the duplicated rows, which left us with a dataframe of 15244 rows and 13 columns.\n3. Outliers: The outlier analysis revealed the presence of extreme values across multiple numerical variables, particularly in price-related features, indicating a skewed distribution and the need for careful preprocessing before modeling.\n            For vehicle_age : most cars fall within a reasonable age range, the outliers are very old or very new cars.\n            For km_driven: there are a large amount of outliers present in this column. These are cars with very high milage, from this we see that some cars are driven much more than
# ...

# %% [markdown]
# ### Section 4: Data Analysis

# %% [markdown]
# #### 4.1 Univariate Analysis of numeric features: Generate histograms for numerical data and infer insights from these visualizations.

# %%
# Plot separate histograms for each numerical column
for col in num_df.columns:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col], bins=30, kde=True)
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
'''
Insights: 

Most numerical features show right-skewed distributions (>0.5), especially selling_price, km_driven, engine, and max_power.

This means most cars fall into lower or mid-range values, with a few extreme cases.

Variables like mileage are more evenly distributed.

The seats variable shows little variation, with most vehicles having 5 seats.

The distributions visually support the presence of outliers identified using the IQR method.
'''
# Out:
# '\nInsights: \n\nMost numerical features show right-skewed distributions (>0.5), especially selling_price, km_driven, engine, and max_power.\n\nThis means most cars fall into lower or mid-range values, with a few extreme cases.\n\nVariables like mileage are more evenly distributed.\n\nThe seats variable shows little variation, with most vehicles having 5 seats.\n\nThe distributions visually support the presence of outliers identified using the IQR method.\n'

# %% [markdown]
# #### 4.2 Examine the skewness in the data and apply appropriate data transformation technique.

# %%
# Examining skeweness using .skew() method for numerical columns
df.skew(numeric_only=True)
# Out:
# vehicle_age      0.682200
# km_driven        0.477708
# mileage          0.275920
# engine          -0.011383
# max_power        0.444041
# seats            0.000000
# selling_price    0.533415
# dtype: float64

# %%
# Right skewed columns (>0.5) are: selling_price, km_driven (slightly right skewed, value is very close to 0.5), vehicle_age, max_power
# We apply Log Transformation to reduce right skew and compress extreme values
selling_price_log = np.log(df['selling_price'] + 1)
print("Skewness after log transform (selling_price):")
print(selling_price_log.skew())
df['selling_price'] = selling_price_log

km_driven_log = np.log(df['km_driven'] + 1)
print("Skewness after log transform (km_driven):")
print(km_driven_log.skew())
df['km_driven'] = km_driven_log

vehicle_age_log = np.log(df['vehicle_age'] + 1)
print("Skewness after log transform (vehicle_age):")
print(vehicle_age_log.skew())
df['vehicle_age'] = vehicle_age_log

max_power_log = np.log(df['max_power'] + 1)
print("Skewness after log transform (max_power):")
print(max_power_log.skew())
df['max_power'] = max_power_log
# Out:
# Skewness after log transform (selling_price):
# -0.545119966564053
# Skewness after log transform (km_driven):
# -1.30503998412256
# Skewness after log transform (vehicle_age):
# -0.223413782309716
# Skewness after log transform (max_power):
# -0.22372760770301275

# %% [markdown]
# #### 4.3 Apply appropriate standardization method wherever applicable.

# %%
# Applying Z-score Normalisation to standardize the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# Columns to be scaled
col_scale = [ 'selling_price', 'km_driven', 'vehicle_age', 'max_power']
X = df[col_scale]

# Scaling
X_scaled = scaler.fit_transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns=col_scale)

# Verify standardization.
X_scaled_df.describe()
# Out:
#        selling_price     km_driven   vehicle_age     max_power
# count   1.096000e+04  1.096000e+04  1.096000e+04  1.096000e+04
# mean    3.084637e-15  2.009747e-17  4.706697e-16 -1.768577e-15
# std     1.000046e+00  1.000046e+00  1.000046e+00  1.000046e+00
# min    -4.463967e+00 -8.105617e+00 -4.351152e+00 -3.353586e+00
# 25%    -6.465846e-01 -4.821657e-01 -5.451995e-01 -5.043637e-01
# 50%     1.037072e-01  2.483217e-01 -1.140506e-01 -4.891109e-02
# 75%     6.966944e-01  7.148297e-01  8.447817e-01  7.597507e-01
# max     1.947091e+00  1.598645e+00  2.052768e+00  2.534321e+00

# %% [markdown]
# #### 4.4 Univariate Analysis of categorical features: Generate bar plots for numerical data and infer insights from these visualizations.

# %%
cat_plot_col = ['brand', 'seller_type', 'fuel_type', 'transmission_type']

df['fuel_type'].value_counts().plot(kind='bar')
plt.title('Distribution of Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('Count')
plt.show()

df['seller_type'].value_counts().plot(kind='bar')
plt.title('Distribution of Seller Type')
plt.xlabel('Seller Type')
plt.ylabel('Count')
plt.show()

df['transmission_type'].value_counts().plot(kind='bar')
plt.title('Distribution of Transmission Type')
plt.xlabel('Transmission Type')
plt.ylabel('Count')
plt.show()

df['brand'].value_counts().plot(kind='bar')
plt.title('Distribution of Brand')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.show()

# %%
'''
Maruti brand accounts for the most common brand, followed by Hyundai and Honda. The rest of the brands have relatively low counts.
The data is imbalanced with respect to brands, theres only a few dominant brands and many with low frequencies.

Manual transmission type if by far the highest frequency, Automatic transmission cars are significantly fewer.
This indicates either preferance popularity or availability.

Petrol and Diesel fuel types are by far the most significant, more so than CNG, LPG and Electric types which have extremely low counts.

Dealers account for majority of listings, while Individuals form a smaller portion and very few Trustmark Dealers.
This indicates that it;s a dealer dominated market.

'''
# Out:
# '\nMaruti brand accounts for the most common brand, followed by Hyundai and Honda. The rest of the brands have relatively low counts.\nThe data is imbalanced with respect to brands, theres only a few dominant brands and many with low frequencies.\n\nManual transmission type if by far the highest frequency, Automatic transmission cars are significantly fewer.\nThis indicates either preferance popularity or availability.\n\nPetrol and Diesel fuel types are by far the most significant, more so than CNG, LPG and Electric types which have extremely low counts.\n\nDealers account for majority of listings, while Individuals form a smaller portion and very few Trustmark Dealers.\nThis indicates that it;s a dealer dominated market.\n\n'

# %% [markdown]
# #### 4.5 Encode categorical features

# %%
# print labels in each categoryical column
print( df['seller_type'])
print( df['fuel_type'] )
print( df['transmission_type'] )

#cat_col_list = ['seller_type', 'fuel_type', 'transmission_type']

# using one-hot encoding for seller_type, fuel_type and transmission_type
df_encoded = pd.get_dummies(df, columns=['seller_type', 'fuel_type', 'transmission_type'], drop_first=True)
#check new columns
df_encoded.head()
#df_encoded.columns
# Out:
# 0        Individual
# 1        Individual
# 2        Individual
# 3        Individual
# 4            Dealer
#             ...
# 10955        Dealer
# 10956        Dealer
# 10957        Dealer
# 10958        Dealer
# 10959        Dealer
# Name: seller_type, Length: 10960, dtype: category
# Categories (3, object): ['Dealer', 'Individual', 'Trustmark Dealer']
# 0        Petrol
# 1        Petrol
# 2        Petrol
# 3        Petrol
# 4        Diesel
#           ...
# 10955    Diesel
# 10956    Petrol
# 10957    Petrol
# 10958    Petrol
# 10959    Diesel
# Name: fuel_type, Length: 10960, dtype: category
# Categories (5, object): ['CNG', 'Diesel', 'Electric', 'LPG', 'Petrol']
# 0        Manual
# 1        Manual
# 2        Manual
# 3        Manual
# 4        Manual
#           ...
# 10955    Manual
# 10956    Manual
# 10957    Manual
# 10958    Manual
# 10959    Manual
# Name: transmission_type, Length: 10960, dtype: category
# Categories (2, object): ['Automatic', 'Manual']
# ...

# %% [markdown]
# #### 4.6 Bivariate and Multivariate Analysis: Calculate the correlation matrix for the numerical variable. Generate heatmap for the correlation matrix, and describe the evident relationships.

# %%
# Calculating correlation matrix
corr_with_target = abs( df.corr(numeric_only=True))
print(corr_with_target)

# Generating a heat map for correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr_with_target, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix Heatmap (Numerical Variables)")
plt.show()
# Out:
#                vehicle_age  km_driven   mileage    engine  max_power  seats  \
# vehicle_age       1.000000   0.590377  0.219933  0.074308   0.053479    NaN
# km_driven         0.590377   1.000000  0.052349  0.224552   0.087783    NaN
# mileage           0.219933   0.052349  1.000000  0.204358   0.309363    NaN
# engine            0.074308   0.224552  0.204358  1.000000   0.882200    NaN
# max_power         0.053479   0.087783  0.309363  0.882200   1.000000    NaN
# seats                  NaN        NaN       NaN       NaN        NaN    NaN
# selling_price     0.634872   0.245044  0.083034  0.492465   0.597046    NaN
#
#                selling_price
# vehicle_age         0.634872
# km_driven           0.245044
# mileage             0.083034
# engine              0.492465
# max_power           0.597046
# seats                    NaN
# selling_price       1.000000

# %%
'''
TheCorrelation analysis shows that selling price is strongly influenced by engine size and maximum power, while milage and vehicle age have a negative relationship with price (price decreases as milage and vehicle age).
Engine size and power are highly correlated with each other, while fuel efficiency decreases as engine size and max pwoer increas.
Seats has no variance and show a weak realionship with selling price.
'''
# Out:
# '\nTheCorrelation analysis shows that selling price is strongly influenced by engine size and maximum power, while milage and vehicle age have a negative relationship with price (price decreases as milage and vehicle age).\nEngine size and power are highly correlated with each other, while fuel efficiency decreases as engine size and max pwoer increas.\nSeats has no variance and show a weak realionship with selling price.\n'

# %% [markdown]
# #### 4.7 Provide detailed observations and conclusions.

# %%
'''
Skewness:

- selling_price is positively skewed (strongly right-skewed; > +0.5)
- km_driven is slightly positively skewed (right-skewed)
- engine is approximately symmetric (skewness value is very cloce to zero)
- milage is roughly near symettric (value also close to zero)
- max_power >0.5: right skewed

A log transformation was succesfully applied to positively skewed numerical variables to reduce skewness and stabilise variance. 
Variables that were approximately symmetric or discrete were left unchanged.

Univariate analysis of categorical features using bar plots shows that the dataset consists only of petrol,diesel,CNG,LPG and Electric vehicles, with petrol and diesel being slthe most common.
Most cars are sold by dealers, while individual and trustmark dealer listings are fewer. 
Manual transmission vehicles dominate over automatic ones. 
Brand distribution is highly imbalanced, with a small number of brands accounting for most vehicles.

We know that categorical columns are brand,seller_type, fuel_type and transmission_type, car_name and model.
We only encode columns seller_type, fuel_type and transmission type because columns brand, car_name and moel simply have too many unique values.
We use one-hot encoding for seller_type, fuel_type and transmission_type because these are nominal variables (they have no natural order).

TheCorrelation analysis shows that selling price is strongly influenced by engine size and maximum power, while milage and vehicle age have a negative relationship with price (price decreases as milage and vehicle age).
Engine size and power are highly correlated with each other, while fuel efficiency decreases as engine size and max pwoer increas.
Seats has no variance and show a weak realionship with selling price.
Performance variables (engine, max_power) are the strongest predictors of price;
Efficiency variables (mileage) move in the opposite direction;
Age matters, but not as strongly as power.

'''
# Out:
# '\nSkewness:\n\n- selling_price is positively skewed (strongly right-skewed; > +0.5)\n- km_driven is slightly positively skewed (right-skewed)\n- engine is approximately symmetric (skewness value is very cloce to zero)\n- milage is roughly near symettric (value also close to zero)\n- max_power >0.5: right skewed\n\nA log transformation was succesfully applied to positively skewed numerical variables to reduce skewness and stabilise variance. \nVariables that were approximately symmetric or discrete were left unchanged.\n\nUnivariate analysis of categorical features using bar plots shows that the dataset consists only of petrol,diesel,CNG,LPG and Electric vehicles, with petrol and diesel being slthe most common.\nMost cars are sold by dealers, while individual and trustmark dealer listings are fewer. \nManual transmission vehicles dominate over automatic ones. \nBrand distribution is highly imbalanced, with a small number of brands accounting for most vehicles.\n\nWe know that categor
# ...

# %% [markdown]
# ### Section 5: Feature Selection

# %% [markdown]
# #### 5.1 Use correlation result for feature selection.

# %%
# Correlation with target vaiable 
corr_target = df.corr(numeric_only=True)['selling_price'].abs()
print(corr_target.sort_values(ascending=False))

# Set correlation threshold
threshold = 0.3

# Select features correlated with target (excluding target itself)
selected_features = corr_target[corr_target >= threshold].index.tolist()
selected_features.remove('selling_price')

print("Selected features based on correlation:")
print(selected_features)
# Out:
# selling_price    1.000000
# vehicle_age      0.634872
# max_power        0.597046
# engine           0.492465
# km_driven        0.245044
# mileage          0.083034
# seats                 NaN
# Name: selling_price, dtype: float64
# Selected features based on correlation:
# ['vehicle_age', 'engine', 'max_power']

# %% [markdown]
# #### 5.2 Select the features according to the K highest score.

# %%
from sklearn.feature_selection import SelectKBest, f_regression

# Features and target
X = df.drop(columns=['selling_price']).select_dtypes(include='number')  # Features
y = df.selling_price  # Target variable
X
# Apply Chi-Squared test
k_selector = SelectKBest(score_func=f_regression, k=3)  # Select top 3 features
X_new = k_selector.fit_transform(X, y)

selected_features = X.columns[k_selector.get_support()]

print(selected_features.tolist())
# Out:
# ['vehicle_age', 'engine', 'max_power']

# %% [markdown]
# #### 5.3 Provide detailed insights about the selected features.

# %%
'''
Strong correlations with selling price: max_power,engine and vehicle_age.
Moderate correlation: milage
Weak correlation: km_driven, seats

K highest score also confirms that selected features are ['vehicle_age', 'engine', 'max_power']
'''
# Out:
# "\nStrong correlations with selling price: max_power,engine and vehicle_age.\nModerate correlation: milage\nWeak correlation: km_driven, seats\n\nK highest score also confirms that selected features are ['vehicle_age', 'engine', 'max_power']\n"
